# %%
import pandas as pd
import numpy as np
import re
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from datetime import timedelta

# %%
path = "results.xlsx"
df = pd.read_excel(path)

# %%
df
# Out:
#                 חותמת זמן                        סוג הרשות  \
# 0 2026-01-25 08:06:02.673   עיר גדולה (מעל 200 אלף תושבים)
# 1 2026-01-25 08:19:10.593   עיר בינונית (50-100 אלף תושבים
# 2 2026-01-25 09:56:22.586   עיר בינונית (50-100 אלף תושבים
# 3 2026-01-25 11:43:50.726  מועצה מקומית (עד 20 אלף תושבים)
# 4 2026-01-25 12:56:24.298      עיר קטנה (20-50 אלף תושבים)
# 5 2026-01-26 07:25:38.226   עיר גדולה (מעל 200 אלף תושבים)
# 6 2026-01-26 20:00:00.920   עיר בינונית (50-100 אלף תושבים
# 7 2026-01-26 20:24:36.521  מועצה מקומית (עד 20 אלף תושבים)
# 8 2026-01-27 00:05:33.523   עיר בינונית (50-100 אלף תושבים
# 9 2026-01-31 17:15:38.420                     מועצה אזורית
#
#        מאפיינים מרכזיים של אוכלוסייה ברשות אשכול חברתי-כלכלי של הרשות  \
# 0                          אוכלוסייה כללית                       7–10
# 1                               חברה חרדית                        1–3
# 2                         אוכלוסייה מעורבת                        4–6
# 3                          אוכלוסייה כללית                       7–10
# 4                          אוכלוסייה כללית                        4–6
# 5  אוכלוסייה כללית, חברה חרדית, חברה ערבית                        1–3
# 6                          אוכלוסייה כללית                        4–6
# 7                               חברה ערבית                        4–6
# 8                          אוכלוסייה כללית                       7–10
# 9                          אוכלוסייה כללית                       7–10
#
#            תחומי ליבה שבהם העומס המשמעותי ביותר כיום  \
# 0                                          מוגבלויות
# 1           משפחה, מוגבלויות, חוק נוער, חוק סדרי דין
# 2  משפחה, אזרחים ותיקים, מוגבלויות, חוק נוער, חוק...
# 3                           אזרחים ותיקים, מוגבלויות
# 4  משפחה, אזרחים ותיקים, מוגבלויות, חוק נוער, חוק...
# 5           משפחה, מוגבלויות, חוק נוער, חוק סדרי דין
# 6  משפחה, אזרחים ותיקים, מוגבלויות, חוק נוער, חוק...
# 7  משפחה, אזרחים ותיקים, מוגבלויות, חוק נוער, חוק...
# 8                                מוגבלויות, חוק נוער
# 9                             חוק נוער, חוק סדרי דין
#
#    עד כמה מדידת עומס לפי מספר תיקים בלבד משקפת בעיניך את המציאות?  \
# 0                                                  5
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  2
# 5                                                  1
# 6                                                  2
# 7                                                  3
# 8                                                  2
# 9                                                  4
#
#   באיזו מידה קיימים אצלכם פערים משמעותיים בין התקינה לבין עומס העבודה בפועל?  \
# 0                                        במידה גבוהה
# 1                                   במידה חריגה מאוד
# 2                                        במידה גבוהה
# 3                                        במידה גבוהה
# 4                                      במידה בינונית
# 5                                        במידה גבוהה
# 6                                        במידה גבוהה
# 7                                        במידה גבוהה
# 8                                        במידה מועטה
# 9                                        במידה מועטה
#
#    עד כמה המשתנים בשאלות הבאות משקפים עומס בפועל בעבודת עו"ס משפחה?                                      שלב התיק (חדש / פעיל / ותיק)(לפי סולם של גיל התיק במחלקה)  \
# 0                                                  1
# 1                                                  3
# 2                                                  2
# 3                                                  4
# 4                                                  2
# 5                                                  3
# 6                                                  3
# 7                                                  3
# 8                                                  3
# 9                                                  2
#
#    רמת אינטנסיביות הטיפול ( לפי מספר העדכונים בתיק בחודש)  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  5
# 6                                                  4
# 7                                                  4
# 8                                                  5
# 9                                                  5
#
#    מספר בני המשפחה המעורבים (לפי מס׳ בני המשפחה שנכללים בתיק)  ...  \
# 0                                                  5           ...
# 1                                                  4           ...
# 2                                                  4           ...
# 3                                                  5           ...
# 4                                                  4           ...
# 5                                                  4           ...
# 6                                                  4           ...
# 7                                                  4           ...
# 8                                                  4           ...
# 9                                                  3           ...
#
#    מבין המשתנים בשאלה הקודמת- מהו המשתנה הכי קריטי לדעתך שמשפיע על המעמסה במוגבלויות?  \
# 0                                                 לא
# 1                         אותם הרכיבים כמו בתיק רגיל
# 2                           מורכבות של מוגבלות ונפש
# 3  זמינות שירותים הן ברמה מקומית והן אזורית. טיפו...
# 4  מחסור בכח אדם.ריבוי ועליה באבחונים אוטיזם.מחסו...
# 5                                 אינטנסיביות הליווי
# 6                                 אינטנסיביות הטיפול
# 7  אנטנסיביות הטיפול שיכול לנבוע ולהיות מושפע מכל...
# 8                              מעורבות/ תפקוד המשפחה
# 9  בעיני - מציאת המענה למגבלה ( שירות , התאמת מסגרת)
#
#    האם יש היבט נוסף בעבודת עו"ס מוגבלויות שלדעתך לא מקבל ביטוי במשתנים שפורטו למדידת המעמסה?  \
# 0                                         כמות תיקים
# 1                                                 לא
# 2  מקרים של מוגבלויות מורכבות עם נפש, קושי באיתור...
# 3  צריך לקחצ בחשבון גם את הביקורים במסגרות ברחבי ...
# 4  תחום מאוד מורכב המחייב התמקצעות וידע-שנים היה ...
# 5  עיסוק בביורוקרטיה בלתי סבירה שניתן לבצע חלקה ב...
# 6                                      כן, עבודת חוק
# 7                          מגוון השירותים שמקבל האדם
# 8                               צורך בסידור חוץ ביתי
# 9  מספר התיקים של הוצאה חוץ ביתית משפיעים עח מעמס...
#
#    האם המשתנים לגבי עוס משפחה משקפים את המעמסה גם לעו״ס אזרחים ותיקים?   \
# 0                                                 כן
# 1                                                 כן
# 2                                                 כן
# 3                                                 כן
# 4                                                 לא
# 5                                                 לא
# 6                                                 לא
# 7                                                 לא
# 8                                                 לא
# 9                                                 כן
#
#   האם נדרש להוסיף מדד של משתנה ספציפי נוסף לצורך מדידת המעמסה לעו״ס ותיקים? לא/כן ולפרט  \
# 0                                                 לא
# 1                                                 לא
# 2                      צורך במעורבות לאור החוק ובחוק
# 3                                          רמת תפקוד
# 4  אזרחים ותיקים בודדים ללא עורף משפחתי-יזום פניה...
# 5     ליווי, תמיכה, בבני משפחה מטפלים שלא מקבל ביטוי
# 6                             כן, קשר ופיקוח במסגרות
# 7  קיומו של צוות אזרחים ותיקים מעובה כגון רכז מענ...
# 8    כן. רמת תפקוד של הותיק  ועורף משפחתי שיש/אין לו
# 9                                                 לא
#
#   האם יש משתנה מיותר לדעתך ביחס לאזרחים ותיקים - מתוך מודל המוצע לעו״ס משפחה? לא/ כן ולפרט מהו  \
# 0                                                 לא
# 1                                                 לא
# 2                                                 לא
# 3                                                 לא
# 4  תחום שיש לחזק.לפתח תוכניות בקהילה. ליזום ולאתר...
# 5                      כן,  ריבוי בעיות ותחומי קושי.
# 6                                                 לא
# 7                                                 לא
# 8                                                 לא
# 9                                                 לא
#
#   תן/י דוגמה לתיק או סוג תיקים שבהם ספירת תיקים בלבד “פספסה” לחלוטין את העומס בפועל (יוכל לשמש אותנו בהצגת הדברים לאיגוד ולאוצר).  \
# 0                                                אין
# 1                            תיקי חו"נ בעצימות גבוהה
# 2  משפחה עם רקע תפקודי קשה, סיכון ילדים, המטופלת ...
# 3  תיק משפחה: זוג + 4 ילדים. צרכים: אבחונים לשני ...
# 4  מקרים מורכבים בחוק הנוער וסידרי דין .כל הסוגיה...
# 5  התערבות חירומית בהוצאת ילדים למרכזי חירום, קלט...
# 6  יש משברים וחרומים שגורמים לאינטנסיביות בטיפול,...
# 7  תיקים במסלול קצר ונקודתי דוגמת מיצוי זכויות הת...
# 8  עובדי משפחה בצוותים שונים. לכל אחד 70 תיקים. א...
# 9  בעיני מדד של מספר תיקים היא דרך מצוינת למדוד מ...
#
#   באיזה תחום לדעתך העיוות בין תקינה לעומס הוא החמור ביותר כיום? ומדוע?  \
# 0          מוגבלויות בגלל הקפיצה המטורפת של האבחונים
# 1  התקינה היחידה שאני מכיר זה עו"ס משפחה. אין תקי...
# 2  מוגבלויות , אזרחים ותיקים, ריבוי פניות, תיקים ...
# 3                             משפחה, זקנה, מוגבלויות
# 4                      מנהל מוגבלויות .אזרחים ותיקים
# 5                           עוס מוגבלויות ועוס משפחה
# 6  משפחות, מוגבלויות ואזרחים ותיקים כי גם אין גבו...
# 7                         משפחה, סדרי דין ומוגבלויות
# 8  מוגבלויות. כי זה תחום עם צרכים שכל הזמן גדלים,...
# 9  אין דרך לבדוק מעמסה של עוס לחוק לנוער / עוס לס...
#
#   מה חשוב בעיניך שהאיגוד יכיר מנק מבט ניהולית לגבי תכנון מעמסה?  \
# 0  עובד לא ישרוד בתפקיד עם יותר מ 80 תיקים וצריך ...
# 1  לא לנתח לפי המערכות מידע משום שיש פערים גדולים...
# 2                                              הנ״ל
# 3                           הנושא חשוב לא פחות מהשכר
# 4  ההשפעה של מעמסה על הבחירה להגיע לעבודה באגף רו...
# 5         ניתוחי עיסוק בהיבט של מאפיינים ותשומות זמן
# 6  עוס שואל על תקינה, על גבול. זה מוכיח את עצנו ש...
# 7                  העדר תקינה לעובדים סוציאלים לחוק
# 8         שמעמסה כוללת מספר משתנים ולא רק מס תיקים.
# 9  1. מבנה אירוגי תקין \n2. מענה של שעות כוננות ל...
#
#   מה חשוב לדעתך שלא ילך לאיבוד במאבק להסדרת מעמסה, מנק מבט ניהולית?  \
# 0                                                  .
# 1  כל מספר שיקבע יהיה התקדמות. חייבים שתהיה החלטה...
# 2  צווים, תסקירים, משפחה המעסיקה ומטופלת במספר מח...
# 3  גיוס ושימור העובדים מחייב אותנו לאפשר עבודה מק...
# 4  חשוב מאוד להבין שהמעסה היא חוליה אחת,חשוב לחזק...
# 5        טווח מסויים ומוגדרהלגמישות בהתאם לשיקול דעת
# 6                            עבודה עם משפחות תחת חוק
# 7  מדד של מספר תיקים בכלל לא משקף המציאות מורכבת ...
# 8               שמדובר בסוגיה מורכבת עם פיתרון משולב
# 9  העלאת גאוות היחידה של עוס במחלקות / אגפים וכמו...
#
#   שם מלא של המנהל ממלא השאלון למקרה שאצטרך מידע נוסף או הבהרות. מלבדי-חומר הגלם הזה יישאר אנונימי.
# 0                                        שירה רייניץ
# 1                                       אבי אקשטיין
# 2                                       רונית זיקרי
# 3                                        דינה וולדמן
# 4                                         נחמה אוחנה
# 5                                    רחל פוסטולובסקי
# 6                                        גאולה ישראל
# 7                                          סוזן אסדי
# 8                                        יואלה תבור
# 9                                            הדס דוד
#
# [10 rows x 27 columns]
