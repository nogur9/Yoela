# %%
import pandas as pd

# %%
df = pd.read_excel("survey_encoded.xlsx")

# %%
df.head()
# Out:
#    סוג הרשות  אשכול חברתי-כלכלי  דיוק מדידה  פער מול תקינה  \
# 0        4.0                  9           5              3
# 1        3.0                  2           3              4
# 2        3.0                  5           3              3
# 3        1.0                  9           2              3
# 4        2.0                  5           2              2
#
#                                                משתנה  ערך משתנה  \
# 0  שלב התיק (חדש / פעיל / ותיק)(לפי סולם של גיל ה...          1
# 1  שלב התיק (חדש / פעיל / ותיק)(לפי סולם של גיל ה...          3
# 2  שלב התיק (חדש / פעיל / ותיק)(לפי סולם של גיל ה...          2
# 3  שלב התיק (חדש / פעיל / ותיק)(לפי סולם של גיל ה...          4
# 4  שלב התיק (חדש / פעיל / ותיק)(לפי סולם של גיל ה...          2
#
#    מאפייני אוכלוסייה_אוכלוסייה כללית  מאפייני אוכלוסייה_אוכלוסייה מעורבת  \
# 0                               True                               False
# 1                              False                               False
# 2                              False                                True
# 3                               True                               False
# 4                               True                               False
#
#    מאפייני אוכלוסייה_חברה חרדית  מאפייני אוכלוסייה_חברה ערבית  \
# 0                         False                         False
# 1                          True                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
#    תחומי העומס_מוגבלויות  תחומי העומס_אזרחים ותיקים  תחומי העומס_חוק סדרי דין  \
# 0                   True                      False                     False
# 1                   True                      False                      True
# 2                   True                       True                      True
# 3                   True                       True                     False
# 4                   True                       True                      True
#
#    תחומי העומס_חוק נוער  תחומי העומס_משפחה  תחומי העומס_תחום נוער וצעירים
# 0                 False              False                          False
# 1                  True               True                          False
# 2                  True               True                           True
# 3                 False              False                          False
# 4                  True               True                          False

# %%
df['ערך משתנה'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## אוכלוסייה

# %%
df['מאפייני אוכלוסייה_אוכלוסייה מעורבת'].mean()
# Out:
# 0.1

# %%
df['מאפייני אוכלוסייה_אוכלוסייה כללית'].mean()
# Out:
# 0.7

# %%
df['מאפייני אוכלוסייה_חברה חרדית'].mean()
# Out:
# 0.2

# %%
df['מאפייני אוכלוסייה_חברה ערבית'].mean()
# Out:
# 0.2

# %% [markdown]
# ## עומס

# %%
df.columns
# Out:
# Index(['סוג הרשות', 'אשכול חברתי-כלכלי', 'דיוק מדידה', 'פער מול תקינה',
#        'משתנה', 'ערך משתנה', 'מאפייני אוכלוסייה_אוכלוסייה כללית',
#        'מאפייני אוכלוסייה_אוכלוסייה מעורבת', 'מאפייני אוכלוסייה_חברה חרדית',
#        'מאפייני אוכלוסייה_חברה ערבית', 'תחומי העומס_מוגבלויות',
#        'תחומי העומס_אזרחים ותיקים', 'תחומי העומס_חוק סדרי דין',
#        'תחומי העומס_חוק נוער', 'תחומי העומס_משפחה',
#        'תחומי העומס_תחום נוער וצעירים'],
#       dtype='object')

# %%
df['תחומי העומס_מוגבלויות'].mean()
# Out:
# 0.9

# %%
df['תחומי העומס_חוק סדרי דין'].mean()
# Out:
# 0.7

# %%
df['תחומי העומס_משפחה'].mean()
# Out:
# 0.6

# %%
df['תחומי העומס_תחום נוער וצעירים'].mean()
# Out:
# 0.1

# %%
df['תחומי העומס_אזרחים ותיקים'].mean()
# Out:
# 0.5

# %%
df['תחומי העומס_חוק נוער'].mean()
# Out:
# 0.8

# %% [markdown]
# ## השוואת שני שדות

# %%
df.columns
# Out:
# Index(['סוג הרשות', 'אשכול חברתי-כלכלי', 'דיוק מדידה', 'פער מול תקינה',
#        'משתנה', 'ערך משתנה', 'מאפייני אוכלוסייה_אוכלוסייה כללית',
#        'מאפייני אוכלוסייה_אוכלוסייה מעורבת', 'מאפייני אוכלוסייה_חברה חרדית',
#        'מאפייני אוכלוסייה_חברה ערבית', 'תחומי העומס_מוגבלויות',
#        'תחומי העומס_אזרחים ותיקים', 'תחומי העומס_חוק סדרי דין',
#        'תחומי העומס_חוק נוער', 'תחומי העומס_משפחה',
#        'תחומי העומס_תחום נוער וצעירים'],
#       dtype='object')

# %%
df.groupby(['מאפייני אוכלוסייה_חברה חרדית', 'משתנה'])['ערך משתנה'].mean()
# Out:
# מאפייני אוכלוסייה_חברה חרדית  משתנה
# False                         מספר בני המשפחה המעורבים (לפי מס׳ בני המשפחה שנכללים בתיק)              4.125
#                               עבודה בין מערכתית ( האם נדרשה וותת״ט ולפי מס גורמים נוספים שיש בתיק)    4.375
#                               עבודה חוקית / רגולטורית ( האם יש מעורבות עו״ס לחוק)                     4.625
#                               ריבוי בעיות ותחומי קושי(לפי מספר המאפיינים בתיק)                        4.500
#                               רמת אינטנסיביות הטיפול ( לפי מספר העדכונים בתיק בחודש)                  4.625
#                               שלב התיק (חדש / פעיל / ותיק)(לפי סולם של גיל התיק במחלקה)               2.500
# True                          מספר בני המשפחה המעורבים (לפי מס׳ בני המשפחה שנכללים בתיק)              4.000
#                               עבודה בין מערכתית ( האם נדרשה וותת״ט ולפי מס גורמים נוספים שיש בתיק)    3.500
#                               עבודה חוקית / רגולטורית ( האם יש מעורבות עו״ס לחוק)                     5.000
#                               ריבוי בעיות ותחומי קושי(לפי מספר המאפיינים בתיק)                        4.500
#                               רמת אינטנסיביות הטיפול ( לפי מספר העדכונים בתיק בחודש)                  4.500
#                               שלב התיק (חדש / פעיל / ותיק)(לפי סולם של גיל התיק במחלקה)               3.000
# Name: ערך משתנה, dtype: float64
